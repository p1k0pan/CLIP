# %%
from clip import clip
from clip import model as c_model
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
from datasets import clip_coco_retrieval_train, clip_coco_retrieval_eval, flickr_dataset
device = 'cuda:1'
model, preprocess = clip.load("ViT-B/32",device=device,jit=False) #Must set jit=False for training

# %%
val_ann_root = '/ltstorage/home/2pan/dataset/COCO/coco_karpathy_val.json'
image_root = '/ltstorage/home/2pan/dataset/COCO/'
val_dataset = clip_coco_retrieval_eval(image_root, val_ann_root, preprocess, False)
val_dataloader = DataLoader(val_dataset,batch_size = 64, num_workers=4, shuffle=False)

# %%
import numpy as np
import torch
@torch.no_grad()
def itm_eval(scores_i2t, scores_t2i, txt2img, img2txt):
    
    #Images->Text 
    ranks = np.zeros(scores_i2t.shape[0])
    for index,score in enumerate(scores_i2t):
        inds = np.argsort(score)[::-1]
        # Score
        rank = 1e20
        # print(inds)
        for i in img2txt[index]:
            # print(i)
            # print(np.where(inds == i))
            tmp = np.where(inds == i)[0][0]
            if tmp < rank:
                rank = tmp
        ranks[index] = rank

    # Compute metrics
    tr1 = 100.0 * len(np.where(ranks < 1)[0]) / len(ranks)
    tr5 = 100.0 * len(np.where(ranks < 5)[0]) / len(ranks)
    tr10 = 100.0 * len(np.where(ranks < 10)[0]) / len(ranks)
  
    #Text->Images 
    ranks = np.zeros(scores_t2i.shape[0])

    print("t2i shape",scores_t2i.shape)
    for index,score in enumerate(scores_t2i): 
        print("index is",index)
        inds = np.argsort(score)[::-1]
        if index == 320:
            print("inds shape",inds)
            print("score is ",score.shape)
        print("txt2img ",txt2img[index]) #64
        print("where",np.where(inds == txt2img[index])) # txt2img能找到64号下标，但是inds只到63
        ranks[index] = np.where(inds == txt2img[index])[0][0]

    # Compute metrics
    ir1 = 100.0 * len(np.where(ranks < 1)[0]) / len(ranks)
    ir5 = 100.0 * len(np.where(ranks < 5)[0]) / len(ranks)
    ir10 = 100.0 * len(np.where(ranks < 10)[0]) / len(ranks)        

    tr_mean = (tr1 + tr5 + tr10) / 3
    ir_mean = (ir1 + ir5 + ir10) / 3
    r_mean = (tr_mean + ir_mean) / 2

    eval_result =  {'txt_r1': tr1,
                    'txt_r5': tr5,
                    'txt_r10': tr10,
                    'txt_r_mean': tr_mean,
                    'img_r1': ir1,
                    'img_r5': ir5,
                    'img_r10': ir10,
                    'img_r_mean': ir_mean,
                    'r_mean': r_mean}
    return eval_result

# %%
import torch
@torch.no_grad()
def small_batch_eval(model, data_loader, device):
    img2txt = data_loader.dataset.img2txt
    txt2img = data_loader.dataset.txt2img
    header = 'Evaluation loss'
    print_freq = 50
    step=0
    eval_result =  {'txt_r1': 0,
                    'txt_r5': 0,
                    'txt_r10': 0,
                    'txt_r_mean': 0,
                    'img_r1': 0,
                    'img_r5': 0,
                    'img_r10': 0,
                    'img_r_mean': 0,
                    'r_mean': 0}
    every_batch_num = []
    for i,(images, index) in enumerate(data_loader):
        step+=1
        captions = []
        for idx in index:
            text_ids = img2txt[idx.item()]
            caption = [data_loader.dataset.text_feat[i] for i in text_ids]
            captions.extend(caption)
            
        every_batch_num.append(len(captions))
        
        text_embeds = torch.cat(captions,dim=0).to(device)
        image_embeds = images.to(device)
        logits_per_image, logits_per_text = model(image_embeds, text_embeds)
        # return logits_per_image.cpu().numpy(), logits_per_text.cpu().numpy()
        i2t = logits_per_image.cpu().numpy()
        t2i = logits_per_text.cpu().numpy()
        # print(t2i.shape)
        # print(t2i[320,63])
        result = itm_eval(i2t, t2i, txt2img, img2txt)
        for key, value in result.items():
            eval_result[key] += value

    # for key, value in eval_result.items():
    #     if key.startswith('txt'):
    #         eval_result[key] = value/ len(img2txt.keys())
    #     if key.startswith('img'):
    #         eval_result[key] = value/ len(txt2img.keys())
    # eval_result['r_mean'] = (eval_result['txt_r_mean'] + eval_result['img_r_mean']) /2
    # print(eval_result)
    print(every_batch_num)
    
small_batch_eval(model, val_dataloader, device)
# i2t, t2i=small_batch_eval(model, val_dataloader, device)
# result = itm_eval(i2t, t2i, val_dataloader.dataset.txt2img, val_dataloader.dataset.img2txt)
# print(result)
len(val_dataloader.dataset.txt2img.keys())
len(val_dataloader.dataset.img2txt.keys())
# Out:
# t2i shape (320, 64)
# index is 0
# txt2img  0
# where (array([0]),)
# index is 1
# txt2img  0
# where (array([0]),)
# index is 2
# txt2img  0
# where (array([0]),)
# index is 3
# txt2img  0
# where (array([0]),)
# index is 4
# txt2img  0
# where (array([0]),)
# index is 5
# txt2img  1
# where (array([1]),)
# index is 6
# txt2img  1
# where (array([1]),)
# index is 7
# txt2img  1
# where (array([0]),)
# index is 8
# txt2img  1
# where (array([0]),)
# index is 9
# txt2img  1
# where (array([0]),)
# index is 10
# txt2img  2
# where (array([0]),)
# index is 11
# txt2img  2
# where (array([0]),)
# index is 12
# txt2img  2
# where (array([0]),)
# index is 13
# txt2img  2
# where (array([0]),)
# index is 14
# txt2img  2
# where (array([0]),)
# index is 15
# txt2img  3
# where (array([1]),)
# index is 16
# txt2img  3
# where (array([0]),)
# index is 17
# txt2img  3
# where (array([0]),)
# index is 18
# txt2img  3
# where (array([0]),)
# index is 19
# txt2img  3
# where (array([0]),)
# index is 20
# txt2img  4
# where (array([1]),)
# index is 21
# txt2img  4
# where (array([2]),)
# index is 22
# txt2img  4
# where (array([0]),)
# index is 23
# txt2img  4
# where (array([0]),)
# index is 24
# txt2img  4
# where (array([0]),)
# index is 25
# txt2img  5
# where (array([0]),)
# index is 26
# txt2img  5
# where (array([0]),)
# index is 27
# txt2img  5
# where (array([0]),)
# index is 28
# txt2img  5
# where (array([0]),)
# index is 29
# txt2img  5
# where (array([0]),)
# index is 30
# txt2img  6
# where (array([0]),)
# index is 31
# txt2img  6
# where (array([0]),)
# index is 32
# txt2img  6
# where (array([0]),)
# index is 33
# txt2img  6
# where (array([0]),)
# index is 34
# txt2img  6
# where (array([0]),)
# index is 35
# txt2img  7
# where (array([0]),)
# index is 36
# txt2img  7
# where (array([0]),)
# index is 37
# txt2img  7
# where (array([0]),)
# index is 38
# txt2img  7
# where (array([0]),)
# index is 39
# txt2img  7
# where (array([0]),)
# index is 40
# txt2img  8
# where (array([0]),)
# index is 41
# txt2img  8
# where (array([0]),)
# index is 42
# txt2img  8
# where (array([0]),)
# index is 43
# txt2img  8
# where (array([0]),)
# index is 44
# txt2img  8
# where (array([0]),)
# index is 45
# txt2img  9
# where (array([0]),)
# index is 46
# txt2img  9
# where (array([0]),)
# index is 47
# txt2img  9
# where (array([0]),)
# index is 48
# txt2img  9
# where (array([0]),)
# index is 49
# txt2img  9
# where (array([0]),)
# index is 50
# txt2img  10
# where (array([0]),)
# index is 51
# txt2img  10
# where (array([0]),)
# index is 52
# txt2img  10
# where (array([0]),)
# index is 53
# txt2img  10
# where (array([0]),)
# index is 54
# txt2img  10
# where (array([0]),)
# index is 55
# txt2img  11
# where (array([0]),)
# index is 56
# txt2img  11
# where (array([0]),)
# index is 57
# txt2img  11
# where (array([0]),)
# index is 58
# txt2img  11
# where (array([0]),)
# index is 59
# txt2img  11
# where (array([0]),)
# index is 60
# txt2img  12
# where (array([0]),)
# index is 61
# txt2img  12
# where (array([0]),)
# index is 62
# txt2img  12
# where (array([0]),)
# index is 63
# txt2img  12
# where (array([0]),)
# index is 64
# txt2img  12
# where (array([0]),)
# index is 65
# txt2img  13
# where (array([0]),)
# index is 66
# txt2img  13
# where (array([0]),)
# index is 67
# txt2img  13
# where (array([0]),)
# index is 68
# txt2img  13
# where (array([0]),)
# index is 69
# txt2img  13
# where (array([0]),)
# index is 70
# txt2img  14
# where (array([0]),)
# index is 71
# txt2img  14
# where (array([0]),)
# index is 72
# txt2img  14
# where (array([0]),)
# index is 73
# txt2img  14
# where (array([0]),)
# index is 74
# txt2img  14
# where (array([0]),)
# index is 75
# txt2img  15
# where (array([0]),)
# index is 76
# txt2img  15
# where (array([0]),)
# index is 77
# txt2img  15
# where (array([0]),)
# index is 78
# txt2img  15
# where (array([0]),)
# index is 79
# txt2img  15
# where (array([0]),)
# index is 80
# txt2img  16
# where (array([2]),)
# index is 81
# txt2img  16
# where (array([0]),)
# index is 82
# txt2img  16
# where (array([2]),)
# index is 83
# txt2img  16
# where (array([2]),)
# index is 84
# txt2img  16
# where (array([2]),)
# index is 85
# txt2img  17
# where (array([0]),)
# index is 86
# txt2img  17
# where (array([0]),)
# index is 87
# txt2img  17
# where (array([0]),)
# index is 88
# txt2img  17
# where (array([0]),)
# index is 89
# txt2img  17
# where (array([0]),)
# index is 90
# txt2img  18
# where (array([0]),)
# index is 91
# txt2img  18
# where (array([9]),)
# index is 92
# txt2img  18
# where (array([1]),)
# index is 93
# txt2img  18
# where (array([1]),)
# index is 94
# txt2img  18
# where (array([7]),)
# index is 95
# txt2img  19
# where (array([0]),)
# index is 96
# txt2img  19
# where (array([0]),)
# index is 97
# txt2img  19
# where (array([1]),)
# index is 98
# txt2img  19
# where (array([0]),)
# index is 99
# txt2img  19
# where (array([0]),)
# index is 100
# txt2img  20
# where (array([0]),)
# index is 101
# txt2img  20
# where (array([0]),)
# index is 102
# txt2img  20
# where (array([0]),)
# index is 103
# txt2img  20
# where (array([0]),)
# index is 104
# txt2img  20
# where (array([0]),)
# index is 105
# txt2img  21
# where (array([0]),)
# index is 106
# txt2img  21
# where (array([0]),)
# index is 107
# txt2img  21
# where (array([0]),)
# index is 108
# txt2img  21
# where (array([0]),)
# index is 109
# txt2img  21
# where (array([0]),)
# index is 110
# txt2img  22
# where (array([0]),)
# index is 111
# txt2img  22
# where (array([0]),)
# index is 112
# txt2img  22
# where (array([0]),)
# index is 113
# txt2img  22
# where (array([0]),)
# index is 114
# txt2img  22
# where (array([0]),)
# index is 115
# txt2img  23
# where (array([0]),)
# index is 116
# txt2img  23
# where (array([0]),)
# index is 117
# txt2img  23
# where (array([0]),)
# index is 118
# txt2img  23
# where (array([0]),)
# index is 119
# txt2img  23
# where (array([0]),)
# index is 120
# txt2img  24
# where (array([0]),)
# index is 121
# txt2img  24
# where (array([0]),)
# index is 122
# txt2img  24
# where (array([0]),)
# index is 123
# txt2img  24
# where (array([0]),)
# index is 124
# txt2img  24
# where (array([0]),)
# index is 125
# txt2img  25
# where (array([1]),)
# index is 126
# txt2img  25
# where (array([1]),)
# index is 127
# txt2img  25
# where (array([0]),)
# index is 128
# txt2img  25
# where (array([1]),)
# index is 129
# txt2img  25
# where (array([1]),)
# index is 130
# txt2img  26
# where (array([0]),)
# index is 131
# txt2img  26
# where (array([0]),)
# index is 132
# txt2img  26
# where (array([0]),)
# index is 133
# txt2img  26
# where (array([1]),)
# index is 134
# txt2img  26
# where (array([0]),)
# index is 135
# txt2img  27
# where (array([0]),)
# index is 136
# txt2img  27
# where (array([0]),)
# index is 137
# txt2img  27
# where (array([0]),)
# index is 138
# txt2img  27
# where (array([0]),)
# index is 139
# txt2img  27
# where (array([0]),)
# index is 140
# txt2img  28
# where (array([0]),)
# index is 141
# txt2img  28
# where (array([0]),)
# index is 142
# txt2img  28
# where (array([0]),)
# index is 143
# txt2img  28
# where (array([0]),)
# index is 144
# txt2img  28
# where (array([0]),)
# index is 145
# txt2img  29
# where (array([0]),)
# index is 146
# txt2img  29
# where (array([0]),)
# index is 147
# txt2img  29
# where (array([3]),)
# index is 148
# txt2img  29
# where (array([0]),)
# index is 149
# txt2img  29
# where (array([2]),)
# index is 150
# txt2img  30
# where (array([46]),)
# index is 151
# txt2img  30
# where (array([0]),)
# index is 152
# txt2img  30
# where (array([0]),)
# index is 153
# txt2img  30
# where (array([0]),)
# index is 154
# txt2img  30
# where (array([1]),)
# index is 155
# txt2img  31
# where (array([0]),)
# index is 156
# txt2img  31
# where (array([0]),)
# index is 157
# txt2img  31
# where (array([0]),)
# index is 158
# txt2img  31
# where (array([0]),)
# index is 159
# txt2img  31
# where (array([0]),)
# index is 160
# txt2img  32
# where (array([3]),)
# index is 161
# txt2img  32
# where (array([3]),)
# index is 162
# txt2img  32
# where (array([0]),)
# index is 163
# txt2img  32
# where (array([2]),)
# index is 164
# txt2img  32
# where (array([1]),)
# index is 165
# txt2img  33
# where (array([0]),)
# index is 166
# txt2img  33
# where (array([0]),)
# index is 167
# txt2img  33
# where (array([0]),)
# index is 168
# txt2img  33
# where (array([0]),)
# index is 169
# txt2img  33
# where (array([0]),)
# index is 170
# txt2img  34
# where (array([0]),)
# index is 171
# txt2img  34
# where (array([0]),)
# index is 172
# txt2img  34
# where (array([0]),)
# index is 173
# txt2img  34
# where (array([0]),)
# index is 174
# txt2img  34
# where (array([0]),)
# index is 175
# txt2img  35
# where (array([0]),)
# index is 176
# txt2img  35
# where (array([0]),)
# index is 177
# txt2img  35
# where (array([0]),)
# index is 178
# txt2img  35
# where (array([1]),)
# index is 179
# txt2img  35
# where (array([1]),)
# index is 180
# txt2img  36
# where (array([0]),)
# index is 181
# txt2img  36
# where (array([0]),)
# index is 182
# txt2img  36
# where (array([0]),)
# index is 183
# txt2img  36
# where (array([0]),)
# index is 184
# txt2img  36
# where (array([0]),)
# index is 185
# txt2img  37
# where (array([0]),)
# index is 186
# txt2img  37
# where (array([0]),)
# index is 187
# txt2img  37
# where (array([0]),)
# index is 188
# txt2img  37
# where (array([0]),)
# index is 189
# txt2img  37
# where (array([0]),)
# index is 190
# txt2img  38
# where (array([0]),)
# index is 191
# txt2img  38
# where (array([0]),)
# index is 192
# txt2img  38
# where (array([0]),)
# index is 193
# txt2img  38
# where (array([0]),)
# index is 194
# txt2img  38
# where (array([0]),)
# index is 195
# txt2img  39
# where (array([0]),)
# index is 196
# txt2img  39
# where (array([0]),)
# index is 197
# txt2img  39
# where (array([0]),)
# index is 198
# txt2img  39
# where (array([0]),)
# index is 199
# txt2img  39
# where (array([0]),)
# index is 200
# txt2img  40
# where (array([0]),)
# index is 201
# txt2img  40
# where (array([0]),)
# index is 202
# txt2img  40
# where (array([1]),)
# index is 203
# txt2img  40
# where (array([0]),)
# index is 204
# txt2img  40
# where (array([1]),)
# index is 205
# txt2img  41
# where (array([0]),)
# index is 206
# txt2img  41
# where (array([0]),)
# index is 207
# txt2img  41
# where (array([0]),)
# index is 208
# txt2img  41
# where (array([0]),)
# index is 209
# txt2img  41
# where (array([0]),)
# index is 210
# txt2img  42
# where (array([0]),)
# index is 211
# txt2img  42
# where (array([1]),)
# index is 212
# txt2img  42
# where (array([1]),)
# index is 213
# txt2img  42
# where (array([0]),)
# index is 214
# txt2img  42
# where (array([0]),)
# index is 215
# txt2img  43
# where (array([0]),)
# index is 216
# txt2img  43
# where (array([0]),)
# index is 217
# txt2img  43
# where (array([0]),)
# index is 218
# txt2img  43
# where (array([0]),)
# index is 219
# txt2img  43
# where (array([0]),)
# index is 220
# txt2img  44
# where (array([0]),)
# index is 221
# txt2img  44
# where (array([1]),)
# index is 222
# txt2img  44
# where (array([0]),)
# index is 223
# txt2img  44
# where (array([1]),)
# index is 224
# txt2img  44
# where (array([0]),)
# index is 225
# txt2img  45
# where (array([0]),)
# index is 226
# txt2img  45
# where (array([0]),)
# index is 227
# txt2img  45
# where (array([0]),)
# index is 228
# txt2img  45
# where (array([0]),)
# index is 229
# txt2img  45
# where (array([0]),)
# index is 230
# txt2img  46
# where (array([0]),)
# index is 231
# txt2img  46
# where (array([0]),)
# index is 232
# txt2img  46
# where (array([0]),)
# index is 233
# txt2img  46
# where (array([0]),)
# index is 234
# txt2img  46
# where (array([0]),)
# index is 235
# txt2img  47
# where (array([0]),)
# index is 236
# txt2img  47
# where (array([0]),)
# index is 237
# txt2img  47
# where (array([0]),)
# index is 238
# txt2img  47
# where (array([0]),)
# index is 239
# txt2img  47
# where (array([0]),)
# index is 240
# txt2img  48
# where (array([0]),)
# index is 241
# txt2img  48
# where (array([0]),)
# index is 242
# txt2img  48
# where (array([0]),)
# index is 243
# txt2img  48
# where (array([0]),)
# index is 244
# txt2img  48
# where (array([0]),)
# index is 245
# txt2img  49
# where (array([0]),)
# index is 246
# txt2img  49
# where (array([1]),)
# index is 247
# txt2img  49
# where (array([1]),)
# index is 248
# txt2img  49
# where (array([0]),)
# index is 249
# txt2img  49
# where (array([1]),)
# index is 250
# txt2img  50
# where (array([0]),)
# index is 251
# txt2img  50
# where (array([0]),)
# index is 252
# txt2img  50
# where (array([1]),)
# index is 253
# txt2img  50
# where (array([0]),)
# index is 254
# txt2img  50
# where (array([0]),)
# index is 255
# txt2img  51
# where (array([0]),)
# index is 256
# txt2img  51
# where (array([0]),)
# index is 257
# txt2img  51
# where (array([0]),)
# index is 258
# txt2img  51
# where (array([0]),)
# index is 259
# txt2img  51
# where (array([0]),)
# index is 260
# txt2img  52
# where (array([0]),)
# index is 261
# txt2img  52
# where (array([0]),)
# index is 262
# txt2img  52
# where (array([0]),)
# index is 263
# txt2img  52
# where (array([0]),)
# index is 264
# txt2img  52
# where (array([0]),)
# index is 265
# txt2img  53
# where (array([0]),)
# index is 266
# txt2img  53
# where (array([3]),)
# index is 267
# txt2img  53
# where (array([0]),)
# index is 268
# txt2img  53
# where (array([0]),)
# index is 269
# txt2img  53
# where (array([1]),)
# index is 270
# txt2img  54
# where (array([1]),)
# index is 271
# txt2img  54
# where (array([1]),)
# index is 272
# txt2img  54
# where (array([0]),)
# index is 273
# txt2img  54
# where (array([0]),)
# index is 274
# txt2img  54
# where (array([1]),)
# index is 275
# txt2img  55
# where (array([0]),)
# index is 276
# txt2img  55
# where (array([0]),)
# index is 277
# txt2img  55
# where (array([0]),)
# index is 278
# txt2img  55
# where (array([0]),)
# index is 279
# txt2img  55
# where (array([0]),)
# index is 280
# txt2img  56
# where (array([0]),)
# index is 281
# txt2img  56
# where (array([0]),)
# index is 282
# txt2img  56
# where (array([0]),)
# index is 283
# txt2img  56
# where (array([2]),)
# index is 284
# txt2img  56
# where (array([0]),)
# index is 285
# txt2img  57
# where (array([0]),)
# index is 286
# txt2img  57
# where (array([0]),)
# index is 287
# txt2img  57
# where (array([0]),)
# index is 288
# txt2img  57
# where (array([1]),)
# index is 289
# txt2img  57
# where (array([0]),)
# index is 290
# txt2img  58
# where (array([0]),)
# index is 291
# txt2img  58
# where (array([0]),)
# index is 292
# txt2img  58
# where (array([0]),)
# index is 293
# txt2img  58
# where (array([0]),)
# index is 294
# txt2img  58
# where (array([0]),)
# index is 295
# txt2img  59
# where (array([0]),)
# index is 296
# txt2img  59
# where (array([0]),)
# index is 297
# txt2img  59
# where (array([0]),)
# index is 298
# txt2img  59
# where (array([0]),)
# index is 299
# txt2img  59
# where (array([1]),)
# index is 300
# txt2img  60
# where (array([0]),)
# index is 301
# txt2img  60
# where (array([0]),)
# index is 302
# txt2img  60
# where (array([0]),)
# index is 303
# txt2img  60
# where (array([0]),)
# index is 304
# txt2img  60
# where (array([0]),)
# index is 305
# txt2img  61
# where (array([0]),)
# index is 306
# txt2img  61
# where (array([0]),)
# index is 307
# txt2img  61
# where (array([0]),)
# index is 308
# txt2img  61
# where (array([0]),)
# index is 309
# txt2img  61
# where (array([0]),)
# index is 310
# txt2img  62
# where (array([0]),)
# index is 311
# txt2img  62
# where (array([0]),)
# index is 312
# txt2img  62
# where (array([0]),)
# index is 313
# txt2img  62
# where (array([0]),)
# index is 314
# txt2img  62
# where (array([0]),)
# index is 315
# txt2img  63
# where (array([1]),)
# index is 316
# txt2img  63
# where (array([1]),)
# index is 317
# txt2img  63
# where (array([0]),)
# index is 318
# txt2img  63
# where (array([0]),)
# index is 319
# txt2img  63
# where (array([1]),)
# t2i shape (321, 64)
# index is 0
# txt2img  0
# where (array([0]),)
# index is 1
# txt2img  0
# where (array([0]),)
# index is 2
# txt2img  0
# where (array([0]),)
# index is 3
# txt2img  0
# where (array([0]),)
# index is 4
# txt2img  0
# where (array([0]),)
# index is 5
# txt2img  1
# where (array([0]),)
# index is 6
# txt2img  1
# where (array([0]),)
# index is 7
# txt2img  1
# where (array([0]),)
# index is 8
# txt2img  1
# where (array([0]),)
# index is 9
# txt2img  1
# where (array([0]),)
# index is 10
# txt2img  2
# where (array([0]),)
# index is 11
# txt2img  2
# where (array([0]),)
# index is 12
# txt2img  2
# where (array([0]),)
# index is 13
# txt2img  2
# where (array([0]),)
# index is 14
# txt2img  2
# where (array([0]),)
# index is 15
# txt2img  3
# where (array([0]),)
# index is 16
# txt2img  3
# where (array([0]),)
# index is 17
# txt2img  3
# where (array([1]),)
# index is 18
# txt2img  3
# where (array([0]),)
# index is 19
# txt2img  3
# where (array([0]),)
# index is 20
# txt2img  4
# where (array([0]),)
# index is 21
# txt2img  4
# where (array([0]),)
# index is 22
# txt2img  4
# where (array([0]),)
# index is 23
# txt2img  4
# where (array([0]),)
# index is 24
# txt2img  4
# where (array([0]),)
# index is 25
# txt2img  5
# where (array([0]),)
# index is 26
# txt2img  5
# where (array([0]),)
# index is 27
# txt2img  5
# where (array([0]),)
# index is 28
# txt2img  5
# where (array([0]),)
# index is 29
# txt2img  5
# where (array([0]),)
# index is 30
# txt2img  6
# where (array([0]),)
# index is 31
# txt2img  6
# where (array([0]),)
# index is 32
# txt2img  6
# where (array([0]),)
# index is 33
# txt2img  6
# where (array([0]),)
# index is 34
# txt2img  6
# where (array([0]),)
# index is 35
# txt2img  7
# where (array([0]),)
# index is 36
# txt2img  7
# where (array([0]),)
# index is 37
# txt2img  7
# where (array([0]),)
# index is 38
# txt2img  7
# where (array([0]),)
# index is 39
# txt2img  7
# where (array([0]),)
# index is 40
# txt2img  8
# where (array([0]),)
# index is 41
# txt2img  8
# where (array([0]),)
# index is 42
# txt2img  8
# where (array([0]),)
# index is 43
# txt2img  8
# where (array([0]),)
# index is 44
# txt2img  8
# where (array([0]),)
# index is 45
# txt2img  9
# where (array([0]),)
# index is 46
# txt2img  9
# where (array([0]),)
# index is 47
# txt2img  9
# where (array([0]),)
# index is 48
# txt2img  9
# where (array([0]),)
# index is 49
# txt2img  9
# where (array([0]),)
# index is 50
# txt2img  10
# where (array([0]),)
# index is 51
# txt2img  10
# where (array([0]),)
# index is 52
# txt2img  10
# where (array([0]),)
# index is 53
# txt2img  10
# where (array([0]),)
# index is 54
# txt2img  10
# where (array([0]),)
# index is 55
# txt2img  11
# where (array([0]),)
# index is 56
# txt2img  11
# where (array([0]),)
# index is 57
# txt2img  11
# where (array([0]),)
# index is 58
# txt2img  11
# where (array([0]),)
# index is 59
# txt2img  11
# where (array([0]),)
# index is 60
# txt2img  12
# where (array([0]),)
# index is 61
# txt2img  12
# where (array([0]),)
# index is 62
# txt2img  12
# where (array([0]),)
# index is 63
# txt2img  12
# where (array([0]),)
# index is 64
# txt2img  12
# where (array([17]),)
# index is 65
# txt2img  13
# where (array([0]),)
# index is 66
# txt2img  13
# where (array([0]),)
# index is 67
# txt2img  13
# where (array([0]),)
# index is 68
# txt2img  13
# where (array([0]),)
# index is 69
# txt2img  13
# where (array([0]),)
# index is 70
# txt2img  14
# where (array([0]),)
# index is 71
# txt2img  14
# where (array([0]),)
# index is 72
# txt2img  14
# where (array([0]),)
# index is 73
# txt2img  14
# where (array([1]),)
# index is 74
# txt2img  14
# where (array([1]),)
# index is 75
# txt2img  15
# where (array([1]),)
# index is 76
# txt2img  15
# where (array([1]),)
# index is 77
# txt2img  15
# where (array([0]),)
# index is 78
# txt2img  15
# where (array([2]),)
# index is 79
# txt2img  15
# where (array([0]),)
# index is 80
# txt2img  16
# where (array([0]),)
# index is 81
# txt2img  16
# where (array([0]),)
# index is 82
# txt2img  16
# where (array([0]),)
# index is 83
# txt2img  16
# where (array([0]),)
# index is 84
# txt2img  16
# where (array([0]),)
# index is 85
# txt2img  17
# where (array([0]),)
# index is 86
# txt2img  17
# where (array([0]),)
# index is 87
# txt2img  17
# where (array([0]),)
# index is 88
# txt2img  17
# where (array([0]),)
# index is 89
# txt2img  17
# where (array([0]),)
# index is 90
# txt2img  18
# where (array([1]),)
# index is 91
# txt2img  18
# where (array([1]),)
# index is 92
# txt2img  18
# where (array([0]),)
# index is 93
# txt2img  18
# where (array([0]),)
# index is 94
# txt2img  18
# where (array([1]),)
# index is 95
# txt2img  19
# where (array([1]),)
# index is 96
# txt2img  19
# where (array([1]),)
# index is 97
# txt2img  19
# where (array([1]),)
# index is 98
# txt2img  19
# where (array([2]),)
# index is 99
# txt2img  19
# where (array([1]),)
# index is 100
# txt2img  20
# where (array([0]),)
# index is 101
# txt2img  20
# where (array([0]),)
# index is 102
# txt2img  20
# where (array([1]),)
# index is 103
# txt2img  20
# where (array([1]),)
# index is 104
# txt2img  20
# where (array([0]),)
# index is 105
# txt2img  21
# where (array([0]),)
# index is 106
# txt2img  21
# where (array([0]),)
# index is 107
# txt2img  21
# where (array([0]),)
# index is 108
# txt2img  21
# where (array([0]),)
# index is 109
# txt2img  21
# where (array([0]),)
# index is 110
# txt2img  22
# where (array([0]),)
# index is 111
# txt2img  22
# where (array([0]),)
# index is 112
# txt2img  22
# where (array([0]),)
# index is 113
# txt2img  22
# where (array([0]),)
# index is 114
# txt2img  22
# where (array([1]),)
# index is 115
# txt2img  23
# where (array([1]),)
# index is 116
# txt2img  23
# where (array([0]),)
# index is 117
# txt2img  23
# where (array([0]),)
# index is 118
# txt2img  23
# where (array([0]),)
# index is 119
# txt2img  23
# where (array([0]),)
# index is 120
# txt2img  24
# where (array([0]),)
# index is 121
# txt2img  24
# where (array([0]),)
# index is 122
# txt2img  24
# where (array([0]),)
# index is 123
# txt2img  24
# where (array([0]),)
# index is 124
# txt2img  24
# where (array([0]),)
# index is 125
# txt2img  25
# where (array([0]),)
# index is 126
# txt2img  25
# where (array([1]),)
# index is 127
# txt2img  25
# where (array([1]),)
# index is 128
# txt2img  25
# where (array([0]),)
# index is 129
# txt2img  25
# where (array([1]),)
# index is 130
# txt2img  26
# where (array([1]),)
# index is 131
# txt2img  26
# where (array([1]),)
# index is 132
# txt2img  26
# where (array([1]),)
# index is 133
# txt2img  26
# where (array([0]),)
# index is 134
# txt2img  26
# where (array([1]),)
# index is 135
# txt2img  27
# where (array([1]),)
# index is 136
# txt2img  27
# where (array([2]),)
# index is 137
# txt2img  27
# where (array([2]),)
# index is 138
# txt2img  27
# where (array([1]),)
# index is 139
# txt2img  27
# where (array([2]),)
# index is 140
# txt2img  28
# where (array([1]),)
# index is 141
# txt2img  28
# where (array([0]),)
# index is 142
# txt2img  28
# where (array([1]),)
# index is 143
# txt2img  28
# where (array([0]),)
# index is 144
# txt2img  28
# where (array([0]),)
# index is 145
# txt2img  29
# where (array([0]),)
# index is 146
# txt2img  29
# where (array([0]),)
# index is 147
# txt2img  29
# where (array([0]),)
# index is 148
# txt2img  29
# where (array([0]),)
# index is 149
# txt2img  29
# where (array([0]),)
# index is 150
# txt2img  30
# where (array([0]),)
# index is 151
# txt2img  30
# where (array([0]),)
# index is 152
# txt2img  30
# where (array([0]),)
# index is 153
# txt2img  30
# where (array([0]),)
# index is 154
# txt2img  30
# where (array([0]),)
# index is 155
# txt2img  31
# where (array([0]),)
# index is 156
# txt2img  31
# where (array([0]),)
# index is 157
# txt2img  31
# where (array([0]),)
# index is 158
# txt2img  31
# where (array([0]),)
# index is 159
# txt2img  31
# where (array([0]),)
# index is 160
# txt2img  32
# where (array([1]),)
# index is 161
# txt2img  32
# where (array([0]),)
# index is 162
# txt2img  32
# where (array([0]),)
# index is 163
# txt2img  32
# where (array([0]),)
# index is 164
# txt2img  32
# where (array([0]),)
# index is 165
# txt2img  33
# where (array([0]),)
# index is 166
# txt2img  33
# where (array([0]),)
# index is 167
# txt2img  33
# where (array([0]),)
# index is 168
# txt2img  33
# where (array([0]),)
# index is 169
# txt2img  33
# where (array([0]),)
# index is 170
# txt2img  34
# where (array([1]),)
# index is 171
# txt2img  34
# where (array([1]),)
# index is 172
# txt2img  34
# where (array([1]),)
# index is 173
# txt2img  34
# where (array([1]),)
# index is 174
# txt2img  34
# where (array([1]),)
# index is 175
# txt2img  35
# where (array([0]),)
# index is 176
# txt2img  35
# where (array([0]),)
# index is 177
# txt2img  35
# where (array([0]),)
# index is 178
# txt2img  35
# where (array([0]),)
# index is 179
# txt2img  35
# where (array([0]),)
# index is 180
# txt2img  36
# where (array([0]),)
# index is 181
# txt2img  36
# where (array([0]),)
# index is 182
# txt2img  36
# where (array([0]),)
# index is 183
# txt2img  36
# where (array([0]),)
# index is 184
# txt2img  36
# where (array([0]),)
# index is 185
# txt2img  37
# where (array([14]),)
# index is 186
# txt2img  37
# where (array([0]),)
# index is 187
# txt2img  37
# where (array([1]),)
# index is 188
# txt2img  37
# where (array([0]),)
# index is 189
# txt2img  37
# where (array([0]),)
# index is 190
# txt2img  38
# where (array([7]),)
# index is 191
# txt2img  38
# where (array([0]),)
# index is 192
# txt2img  38
# where (array([0]),)
# index is 193
# txt2img  38
# where (array([0]),)
# index is 194
# txt2img  38
# where (array([0]),)
# index is 195
# txt2img  39
# where (array([2]),)
# index is 196
# txt2img  39
# where (array([0]),)
# index is 197
# txt2img  39
# where (array([0]),)
# index is 198
# txt2img  39
# where (array([0]),)
# index is 199
# txt2img  39
# where (array([2]),)
# index is 200
# txt2img  40
# where (array([34]),)
# index is 201
# txt2img  40
# where (array([0]),)
# index is 202
# txt2img  40
# where (array([0]),)
# index is 203
# txt2img  40
# where (array([0]),)
# index is 204
# txt2img  40
# where (array([0]),)
# index is 205
# txt2img  41
# where (array([59]),)
# index is 206
# txt2img  41
# where (array([2]),)
# index is 207
# txt2img  41
# where (array([0]),)
# index is 208
# txt2img  41
# where (array([0]),)
# index is 209
# txt2img  41
# where (array([0]),)
# index is 210
# txt2img  42
# where (array([21]),)
# index is 211
# txt2img  42
# where (array([1]),)
# index is 212
# txt2img  42
# where (array([1]),)
# index is 213
# txt2img  42
# where (array([1]),)
# index is 214
# txt2img  42
# where (array([1]),)
# index is 215
# txt2img  43
# where (array([3]),)
# index is 216
# txt2img  43
# where (array([3]),)
# index is 217
# txt2img  43
# where (array([0]),)
# index is 218
# txt2img  43
# where (array([0]),)
# index is 219
# txt2img  43
# where (array([0]),)
# index is 220
# txt2img  44
# where (array([0]),)
# index is 221
# txt2img  44
# where (array([0]),)
# index is 222
# txt2img  44
# where (array([0]),)
# index is 223
# txt2img  44
# where (array([0]),)
# index is 224
# txt2img  44
# where (array([3]),)
# index is 225
# txt2img  45
# where (array([2]),)
# index is 226
# txt2img  45
# where (array([3]),)
# index is 227
# txt2img  45
# where (array([3]),)
# index is 228
# txt2img  45
# where (array([2]),)
# index is 229
# txt2img  45
# where (array([1]),)
# index is 230
# txt2img  46
# where (array([8]),)
# index is 231
# txt2img  46
# where (array([0]),)
# index is 232
# txt2img  46
# where (array([0]),)
# index is 233
# txt2img  46
# where (array([4]),)
# index is 234
# txt2img  46
# where (array([2]),)
# index is 235
# txt2img  47
# where (array([1]),)
# index is 236
# txt2img  47
# where (array([2]),)
# index is 237
# txt2img  47
# where (array([1]),)
# index is 238
# txt2img  47
# where (array([1]),)
# index is 239
# txt2img  47
# where (array([1]),)
# index is 240
# txt2img  48
# where (array([0]),)
# index is 241
# txt2img  48
# where (array([0]),)
# index is 242
# txt2img  48
# where (array([0]),)
# index is 243
# txt2img  48
# where (array([1]),)
# index is 244
# txt2img  48
# where (array([0]),)
# index is 245
# txt2img  49
# where (array([38]),)
# index is 246
# txt2img  49
# where (array([1]),)
# index is 247
# txt2img  49
# where (array([0]),)
# index is 248
# txt2img  49
# where (array([0]),)
# index is 249
# txt2img  49
# where (array([0]),)
# index is 250
# txt2img  50
# where (array([12]),)
# index is 251
# txt2img  50
# where (array([1]),)
# index is 252
# txt2img  50
# where (array([0]),)
# index is 253
# txt2img  50
# where (array([0]),)
# index is 254
# txt2img  50
# where (array([0]),)
# index is 255
# txt2img  51
# where (array([3]),)
# index is 256
# txt2img  51
# where (array([0]),)
# index is 257
# txt2img  51
# where (array([0]),)
# index is 258
# txt2img  51
# where (array([2]),)
# index is 259
# txt2img  51
# where (array([0]),)
# index is 260
# txt2img  52
# where (array([8]),)
# index is 261
# txt2img  52
# where (array([0]),)
# index is 262
# txt2img  52
# where (array([0]),)
# index is 263
# txt2img  52
# where (array([0]),)
# index is 264
# txt2img  52
# where (array([0]),)
# index is 265
# txt2img  53
# where (array([60]),)
# index is 266
# txt2img  53
# where (array([1]),)
# index is 267
# txt2img  53
# where (array([1]),)
# index is 268
# txt2img  53
# where (array([1]),)
# index is 269
# txt2img  53
# where (array([1]),)
# index is 270
# txt2img  54
# where (array([8]),)
# index is 271
# txt2img  54
# where (array([0]),)
# index is 272
# txt2img  54
# where (array([0]),)
# index is 273
# txt2img  54
# where (array([0]),)
# index is 274
# txt2img  54
# where (array([0]),)
# index is 275
# txt2img  55
# where (array([49]),)
# index is 276
# txt2img  55
# where (array([0]),)
# index is 277
# txt2img  55
# where (array([0]),)
# index is 278
# txt2img  55
# where (array([0]),)
# index is 279
# txt2img  55
# where (array([0]),)
# index is 280
# txt2img  56
# where (array([24]),)
# index is 281
# txt2img  56
# where (array([2]),)
# index is 282
# txt2img  56
# where (array([0]),)
# index is 283
# txt2img  56
# where (array([2]),)
# index is 284
# txt2img  56
# where (array([1]),)
# index is 285
# txt2img  57
# where (array([0]),)
# index is 286
# txt2img  57
# where (array([0]),)
# index is 287
# txt2img  57
# where (array([0]),)
# index is 288
# txt2img  57
# where (array([0]),)
# index is 289
# txt2img  57
# where (array([0]),)
# index is 290
# txt2img  58
# where (array([34]),)
# index is 291
# txt2img  58
# where (array([0]),)
# index is 292
# txt2img  58
# where (array([0]),)
# index is 293
# txt2img  58
# where (array([0]),)
# index is 294
# txt2img  58
# where (array([0]),)
# index is 295
# txt2img  59
# where (array([15]),)
# index is 296
# txt2img  59
# where (array([1]),)
# index is 297
# txt2img  59
# where (array([0]),)
# index is 298
# txt2img  59
# where (array([1]),)
# index is 299
# txt2img  59
# where (array([0]),)
# index is 300
# txt2img  60
# where (array([41]),)
# index is 301
# txt2img  60
# where (array([0]),)
# index is 302
# txt2img  60
# where (array([0]),)
# index is 303
# txt2img  60
# where (array([0]),)
# index is 304
# txt2img  60
# where (array([0]),)
# index is 305
# txt2img  61
# where (array([6]),)
# index is 306
# txt2img  61
# where (array([0]),)
# index is 307
# txt2img  61
# where (array([0]),)
# index is 308
# txt2img  61
# where (array([0]),)
# index is 309
# txt2img  61
# where (array([0]),)
# index is 310
# txt2img  62
# where (array([45]),)
# index is 311
# txt2img  62
# where (array([0]),)
# index is 312
# txt2img  62
# where (array([0]),)
# index is 313
# txt2img  62
# where (array([0]),)
# index is 314
# txt2img  62
# where (array([0]),)
# index is 315
# txt2img  63
# where (array([53]),)
# index is 316
# txt2img  63
# where (array([0]),)
# index is 317
# txt2img  63
# where (array([0]),)
# index is 318
# txt2img  63
# where (array([0]),)
# index is 319
# txt2img  63
# where (array([0]),)
# index is 320
# inds shape [63 13 14 30 51 19 10 38 61 11 58 59 18 17 54 37 21 49 60 35 16 40 36  1
#  48 52 26 33 22 34 23 31 32 57 15 12  0  7  3  2 39 55 56 50  8 46  5 24
#  53 43 20 62 42  6  4 25 44  9 47 29 41 45 28 27]
# score is  (64,)
# txt2img  64
# where (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 50
#      41     # for key, value in eval_result.items():
#      42     #     if key.startswith('txt'):
#      43     #         eval_result[key] = value/ len(img2txt.keys())
#    (...)
#      46     # eval_result['r_mean'] = (eval_result['txt_r_mean'] + eval_result['img_r_mean']) /2
#      47     # print(eval_result)
#      48     print(every_batch_num)
# ---> 50 small_batch_eval(model, val_dataloader, device)
#      51 # i2t, t2i=small_batch_eval(model, val_dataloader, device)
#      52 # result = itm_eval(i2t, t2i, val_dataloader.dataset.txt2img, val_dataloader.dataset.img2txt)
#      53 # print(result)
#      54 len(val_dataloader.dataset.txt2img.keys())
#
# File ~/miniconda3/envs/blip/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[46], line 37, in small_batch_eval(model, data_loader, device)
#      34 t2i = logits_per_text.cpu().numpy()
#      35 # print(t2i.shape)
#      36 # print(t2i[320,63])
# ---> 37 result = itm_eval(i2t, t2i, txt2img, img2txt)
#      38 for key, value in result.items():
#      39     eval_result[key] += value
#
# File ~/miniconda3/envs/blip/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[45], line 38, in itm_eval(scores_i2t, scores_t2i, txt2img, img2txt)
#      36     print("txt2img ",txt2img[index]) #64
#      37     print("where",np.where(inds == txt2img[index])) # txt2img能找到64号下标，但是inds只到63
# ---> 38     ranks[index] = np.where(inds == txt2img[index])[0][0]
#      40 # Compute metrics
#      41 ir1 = 100.0 * len(np.where(ranks < 1)[0]) / len(ranks)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
